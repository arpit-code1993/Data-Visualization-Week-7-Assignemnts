# %% [markdown]
# <b>Your Turn</b>
#
# Can you make a dataframe from a file you have uploaded and imported
# on your own? Let's find out. Go to https://www.census.gov/support/
# USACdataDownloads.html and download one of the Excel datafiles at the
# bottom of the page. Now, try to import that data into Python.

# %%
import pandas as pd

# %%
xls = pd.ExcelFile(r'C:\Users\RajKumar\Downloads\Crime_rate_US_census.xls')

# %%
df1 = pd.read_excel(xls, 'Sheet1')
df2 = pd.read_excel(xls, 'Sheet2')
df3 = pd.read_excel(xls, 'Sheet3')
df4 = pd.read_excel(xls, 'Sheet4')

# %%
df1.head()
# Out:
#         Areaname  STCOU  CRM250203F  CRM250203D  CRM250203N1  CRM250203N2  \
# 0  UNITED STATES      0           0     6571138            0            0
# 1        ALABAMA   1000           0      117567            0            0
# 2    Autauga, AL   1001           0        1235            0            0
# 3    Baldwin, AL   1003           0        3128            0            0
# 4    Barbour, AL   1005           1         469         7020            0
#
#    CRM250204F  CRM250204D  CRM250204N1  CRM250204N2  ...  CRM260182N1  \
# 0           0     6578616            0            0  ...            0
# 1           0      118860            0            0  ...            0
# 2           1        1162         7020            0  ...            0
# 3           1        2145         7020            0  ...            0
# 4           1         610         7020            0  ...            0
#
#    CRM260182N2  CRM260183F  CRM260183D  CRM260183N1  CRM260183N2  CRM260184F  \
# ...

# %%
df2.head()
# Out:
#         Areaname  STCOU  CRM260185F  CRM260185D  CRM260185N1  CRM260185N2  \
# 0  UNITED STATES      0           0     1081355            0            0
# 1        ALABAMA   1000           0       10253            0            0
# 2    Autauga, AL   1001           0          41            0            0
# 3    Baldwin, AL   1003           0          82            0            0
# 4    Barbour, AL   1005           0          12            0            0
#
#    CRM260186F  CRM260186D  CRM260186N1  CRM260186N2  ...  CRM260192N1  \
# 0           0     1198980            0            0  ...            0
# 1           0       10516            0            0  ...            0
# 2           0          40            0            0  ...            0
# 3           0         141            0            0  ...         7020
# 4           0          22            0            0  ...         7020
#
#    CRM260192N2  CRM260193F  CRM260193D  CRM260193N1  CRM260193N2  CRM260194F  \
# ...

# %%
df3.head()
# Out:
#         Areaname  STCOU  CRM260195F  CRM260195D  CRM260195N1  CRM260195N2  \
# 0  UNITED STATES      0           0     1389582            0            0
# 1        ALABAMA   1000           0       14523            0            0
# 2    Autauga, AL   1001           0          81            0            0
# 3    Baldwin, AL   1003           0         124            0            0
# 4    Barbour, AL   1005           0          15            0            0
#
#    CRM260196F  CRM260196D  CRM260196N1  CRM260196N2  ...  CRM260202N1  \
# 0           1     1277951         7024            0  ...            0
# 1           0       15445            0            0  ...            0
# 2           0          73            0            0  ...         7020
# 3           0         148            0            0  ...         7020
# 4           1          18         7020            0  ...         7020
#
#    CRM260202N2  CRM260203F  CRM260203D  CRM260203N1  CRM260203N2  CRM260204F  \
# ...

# %%
df4.head()
# Out:
#         Areaname  STCOU  CRM260205F  CRM260205D  CRM260205N1  CRM260205N2  \
# 0  UNITED STATES      0           0     1196608            0            0
# 1        ALABAMA   1000           0       10796            0            0
# 2    Autauga, AL   1001           0         112            0            0
# 3    Baldwin, AL   1003           1         137         7020            0
# 4    Barbour, AL   1005           1           7         7020            0
#
#    CRM260206F  CRM260206D  CRM260206N1  CRM260206N2  CRM260207F  CRM260207D  \
# 0           0     1157392            0            0           0     1063112
# 1           0       11903            0            0           0       12435
# 2           0          94            0            0           1         101
# 3           1         115         7020            0           1         238
# 4           1           1         7020            0           0           2
#
# ...
